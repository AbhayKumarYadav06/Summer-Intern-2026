# %%
d = {'name':'python', 'age': 30, 'city': 'patal lok', 'd2': {'name':'bhaisa', 'age': 50000, 'city': 'yamraj ka ghar'}}
print(d['name'])
print(d['age'])
print(d['city'])
print(d['d2']['name'])
print(d['d2']['age'])
print(d['d2']['city'])

print(d.keys())
print(d.values())
print(d.items())

d['profession'] = 'soul snatching'
print(d)
# Out:
# python
# 30
# patal lok
# bhaisa
# 50000
# yamraj ka ghar
# dict_keys(['name', 'age', 'city', 'd2'])
# dict_values(['python', 30, 'patal lok', {'name': 'bhaisa', 'age': 50000, 'city': 'yamraj ka ghar'}])
# dict_items([('name', 'python'), ('age', 30), ('city', 'patal lok'), ('d2', {'name': 'bhaisa', 'age': 50000, 'city': 'yamraj ka ghar'})])
# {'name': 'python', 'age': 30, 'city': 'patal lok', 'd2': {'name': 'bhaisa', 'age': 50000, 'city': 'yamraj ka ghar'}, 'profession': 'soul snatching'}
