# %%
print("hello world")
# Out:
# hello world

# %%
num = 10

if (num > 0):
    print("positive number")
elif (num == 0):
    print("zero")
else:
    print("negative number")

print(num, "\n" "the end")
# Out:
# negative number
# -9
# the end

# %%
i=0
for i in range(0, 20, 2):
    print(i, end=" ")
    print("hello world")
# Out:
# 0 hello world
# 2 hello world
# 4 hello world
# 6 hello world
# 8 hello world
# 10 hello world
# 12 hello world
# 14 hello world
# 16 hello world
# 18 hello world

# %%
tabnum = int(input("Enter a numberto print a table: "))
for i in range (1, 11):
    print(tabnum, "x", i, "= ", tabnum*i)
print("the end")
# Out:
# 45 x 1 =  45
# 45 x 2 =  90
# 45 x 3 =  135
# 45 x 4 =  180
# 45 x 5 =  225
# 45 x 6 =  270
# 45 x 7 =  315
# 45 x 8 =  360
# 45 x 9 =  405
# 45 x 10 =  450
# the end

# %%
for i in range(1, 5):
    for j in range(1, 5):
        print("*", end=" ")
    print("*")
# Out:
# * * * * *
# * * * * *
# * * * * *
# * * * * *

# %%
num = int(input("Enter a number: "))
for i in range(1, num+1):
    print("*" * i)
print("stop")
for i in range(num, 0, -1):
    print("*" * i)
# Out:
# *
# **
# ***
# ****
# *****
# ******
# stop
# ******
# *****
# ****
# ***
# **
# *

# %%
for i in range(1, num+1):
    print("*" * i, end=" ")
    print(" " * (num-i)*2, end=" ")
    print("*" * i)

for i in range(num, 0, -1):
    print("*" * i, end=" ")
    print(" " * (num-i)*2, end=" ")
    print("*" * i)
# Out:
# *            *
# **          **
# ***        ***
# ****      ****
# *****    *****
# ******  ******
# ******  ******
# *****    *****
# ****      ****
# ***        ***
# **          **
# *            *

# %%
for i in range(1, num+1):
    print(" " * i, end=" ")
    print("*" * (((num-i)*2)-1), end=" ")
    print(" " * i)

for i in range(num-1, 0, -1):
    print(" " * i, end=" ")
    print("*" * (((num-i)*2)-1), end=" ")
    print(" " * i)
# Out:
#   *********
#    *******
#     *****
#      ***
#       *
#
#       *
#      ***
#     *****
#    *******
#   *********
