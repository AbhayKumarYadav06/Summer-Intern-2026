# %%
print("first line")
# Out:
# first line

# %%
n1 = int(input("Enter first number: "))
print(n1)
# Out:
# 123456

# %%
print(f"there is input: {n1:.2f} in the program.")
# Out:
# there is input: 123456.00 in the program.

# %%
a= "this is a python. code is very good"
print(a.find("is"))
print(a.find("is", 3))
print(a.count("is"))
print(a.index("is"))
print(a.ljust(40, "-"))

print(a.center(40))

print(a.lstrip())
print(a.rstrip())


print(a.replace("is", "was"))
print(a.split())
#print(a.strip())
# Out:
# 2
# 5
# 3
# 2
# this is a python. code is very good-----
#   this is a python. code is very good
# this is a python. code is very good
# this is a python. code is very good
# thwas was a python. code was very good
# ['this', 'is', 'a', 'python.', 'code', 'is', 'very', 'good']

# %%
a= "-"
sequence = ("a", "b", "c")
print(a.join(sequence))


print("a" in sequence)
print(a in sequence)


b = "hello world"
encode = str.maketrans("aeiou", "12345")
b = b.translate(encode)
print(b)
print(b.upper())
# Out:
# a-b-c
# True
# False
# h2ll4 w4rld
# H2LL4 W4RLD

# %%
char1 = input("Enter a character: ")
print(ord(char1))
# Out:
# 102
